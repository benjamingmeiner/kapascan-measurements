# %%
from utils.measure import align
# %matplotlib inline

# %%
settings = {
    'sensors': ['1739'],
    'sampling_time': 0.256,
    'data_points': 50,
    'extent': ((-1.5+18.5, 1.5+18.5, 1), (-1.5+11, 1.5+11, 1)),
    'mode': 'absolute',
    'direction': ('x', 'y'),
    'change_direction': False
    }

# %%
x, y, z, T = align(settings)
