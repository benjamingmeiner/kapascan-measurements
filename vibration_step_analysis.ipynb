# %%
import matplotlib.pyplot as plt
import numpy as np
from utils.plot import plot
from utils.analyze import load_raw_data
# %matplotlib notebook

# %%
directory = "vibration_step"
#numbers = range(1,21)

# %%
def cat(data):
    nr_of_sensors = data[0].shape[0]
    data_per_sensor = [[data[i][s] for i in range(len(data))] for s in range(nr_of_sensors)]
    return [np.concatenate(d) for d in data_per_sensor]

# %%
data, time, settings = load_raw_data(directory)
len(data)
# Out:
# array([ 210.29026675,  207.67304182])

# %%
t = np.linspace(0, time[0][1] - time[0][0], len(data[0][0]))
z = data[0][0]

# %%
xmin = 4.22
fig, ax = plt.subplots(1,1)
ax.plot(t - xmin, z)
ax.set_xlim([0,0.8])
ax.set_ylim([273.65, 274.7])
ax.set_xlabel(r"$t$ [s]")
ax.set_ylabel(r"$z$ [µm]")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(d1 - d1[0])
plt.plot(d2 - d2[0])
# Out:
# <img src="data:image/png;base64,..." width="944">

# %%
settings
# Out:
# [{'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']},
#  {'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']},
#  {'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']},
#  {'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']},
#  {'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']}]
