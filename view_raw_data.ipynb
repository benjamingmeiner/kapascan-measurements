# %%
import matplotlib.pyplot as plt
import numpy as np
from utils.plot import plot
from utils.analyze import load_raw_data
# %matplotlib notebook

# %%
directory = "dualtest_electrode_sirup"
numbers = range(1,21)

# %%
def cat(data):
    sensors = data[0].shape[0]
    data_sorted = [[data[i][s] for i in range(len(data))] for s in range(sensors)]
    return [np.concatenate(d) for d in data_sorted]

# %%
data, time, settings = load_raw_data(directory, numbers)

# %%
d1, d2 = cat(data)

# %%
plt.plot(d1 - d1[0])
plt.plot(d2 - d2[0])
# Out:
# <img src="data:image/png;base64,..." width="944">

# %%
settings
# Out:
# [{'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']},
#  {'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']},
#  {'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']},
#  {'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']},
#  {'data_points': 30000,
#   'mode': 'continuous',
#   'sampling_time': 384,
#   'sensors': ['2011', '2012']}]
