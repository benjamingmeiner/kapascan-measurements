# %%
from utils.plot import plot
from utils.analyze import load_data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
directory = "micro_epsilon_stability_check"
numbers = range(20)

# %%
x, y, z, T, t = load_data(directory, numbers)

# %%
def restruct(x):
    x1, x2 = [], []
    for xi in x:
        x1.append(xi[0].ravel())
        x2.append(xi[1].ravel())
    return np.concatenate(x1).flatten(), np.concatenate(x2).flatten()

# %%
z1, z2 = restruct(z)
tf = np.concatenate(t).flatten()
Tf = np.concatenate(T).flatten()

# %%
tr = tf.reshape(-1, 140).mean(1)
z1r = z1.reshape(-1, 140).mean(1)
z2r = z2.reshape(-1, 140).mean(1)

# %%
plt.plot(tf, z1-z1[0])
plt.plot(tf, z2-z2[0])
plt.plot(tf, Tf-Tf[0]+10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tf[1] - tf[0]
# Out:
# 26.99032998085022

# %%
t[0][2] - t[0][1]
# Out:
# 26.669481754302979

# %%
plt.plot(tf, "-x")
# Out:
# <img src="data:image/png;base64,..." width="640">
