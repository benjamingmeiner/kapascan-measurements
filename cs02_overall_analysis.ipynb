# %%
from utils.plot import plot
from utils.analyze import load_data
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
directory = "cs02_background"
numbers = range(4)

# %%
x, y, z, T, t = load_data(directory, numbers)

# %%
for z1, z2, T1, T2, d1, d2 in zip(z, z[1:], T, T[1:], dates, dates[1:]):
    #dd = [(d2i - d1i).total_seconds() for d1i, d2i in zip(d1, d2)]
    plt.figure()
    plt.plot(z2[0].flatten() - z1[0].flatten())
    plt.plot(T2.flatten() - T1.flatten())
    plot(x[0], y[0], z2[0] - z1[0])
    plot(x[0], y[0], T2 - T1)

# %%
plt.plot(dates, z[5][0].flatten()- z[4][0].flatten())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dates = [[datetime.datetime.fromtimestamp(tii) for tii in ti] for ti in t]

# %%
datetime.timedelta.total_seconds
# Out:
# <method 'total_seconds' of 'datetime.timedelta' objects>

# %%
12450 / 60 / 60
# Out:
# 3.4583333333333335

# %%
DL = 1e-6
DT = 0.5
a = 23.1e-6
L0 = DL / (a * DT)
L0 * 100
# Out:
# 8.658008658008658
