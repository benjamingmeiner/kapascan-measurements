# %%
from utils.log import configure_logging
from utils.measure import align_raw, save_raw
from kapascan.helper import query_yes_no
# %matplotlib inline

# %%
configure_logging(debug=False)

# %%
sampling_time = 1 #ms
measurement_time = 2 #s
data_points = round(measurement_time / sampling_time * 1000)
settings = {
    'sensors': ['1161'],
    'sampling_time': sampling_time,
    'data_points': data_points,
    'mode': 'continuous',
}

# %%
data, times = align_raw(settings)

# %%
directory = "vibrations"
if query_yes_no("Do you want to save data?", default="yes"):
    save_raw(data, times, settings, directory, "align_raw.ipynb", i=0)
# Out:
# Do you want to save data? [Y/n] --->  y
